# %%
import tensorflow as tf
from tensorflow.contrib import slim
from tensorflow.examples.tutorials.mnist import input_data
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import os
from util import plot

# %% [markdown]
# ## Setting; parameter & data

# %%
mb_size = 32
X_dim = 784
z_dim = 64
h_dim = 128
D_out_dim = X_dim

lr = 1e-3
gamma = 0.9
#lr = 9e-4
#gamma = 0.9
lambda_k = 1e-3
k_curr = 0

mnist = input_data.read_data_sets('./MNIST_data', one_hot=True)

save_image_path = 'BEGAN_fixed'

if not os.path.exists('out/{}/'.format(save_image_path)):
    os.makedirs('out/{}/'.format(save_image_path))
# Out:
# Extracting ./MNIST_data/train-images-idx3-ubyte.gz
# Extracting ./MNIST_data/train-labels-idx1-ubyte.gz
# Extracting ./MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting ./MNIST_data/t10k-labels-idx1-ubyte.gz

# %% [markdown]
# ## Model

# %%
def sample_z(m, n):
    return np.random.uniform(-1., 1., size=[m, n])


def generator(z):
    with tf.variable_scope('G'):
        G_h1 = slim.fully_connected(z, z_dim, activation_fn=tf.nn.relu)
        G_prob = slim.fully_connected(G_h1, X_dim, activation_fn=tf.nn.sigmoid)
    return G_prob


def discriminator(x, reuse=False):
    with tf.variable_scope('D', reuse=reuse):
        D_h1 = slim.fully_connected(x, z_dim, activation_fn=tf.nn.relu)
        ae_x = slim.fully_connected(D_h1, D_out_dim, activation_fn=None)
#    return tf.reduce_mean(tf.reduce_sum(tf.abs(x - X_recon), 1))
    return ae_x



def AE_loss(x, ae_x):
    # loss from paper
    # loss from https://github.com/carpedm20/BEGAN-tensorflow.git
    loss = tf.reduce_mean(tf.reduce_sum(tf.abs(ae_x - x), 1))
    
    # loss from https://github.com/wiseodd/generative-models/blob/master/GAN/boundary_equilibrium_gan/began_tensorflow.py
    # loss from https://github.com/hwalsuklee/tensorflow-generative-model-collections/blob/master/BEGAN.py
    # loss = tf.reduce_mean(tf.reduce_sum((x - ae_x)**2, 1))
    return loss

graph = tf.reset_default_graph()
tf.set_random_seed(1)
X = tf.placeholder(tf.float32, shape=[None, X_dim])
z = tf.placeholder(tf.float32, shape=[None, z_dim])
k = tf.Variable(0., trainable=False)


G_sample = generator(z)

ae_x = discriminator(X)
ae_fake = discriminator(G_sample, reuse=True)

# %% [markdown]
# ## Loss  & Optimizer

# %%
D_real = AE_loss(X, ae_x)
D_fake = AE_loss(G_sample, ae_fake)

D_loss = D_real - k*D_fake
G_loss = D_fake



theta_G = tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, scope='G')
theta_D = tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, scope='D')


D_solver = (tf.train.AdamOptimizer(learning_rate=lr)
            .minimize(D_loss, var_list=theta_D))
G_solver = (tf.train.AdamOptimizer(learning_rate=lr)
            .minimize(G_loss, var_list=theta_G))

balance = gamma * D_real - D_fake
measure = D_real + tf.abs(balance)
with tf.control_dependencies([D_solver, G_solver]):
    k_update = tf.assign(k, tf.clip_by_value(k + lambda_k * balance, 0, 1))

# %%
sess = tf.InteractiveSession()
sess.run(tf.global_variables_initializer())


for it in range(20001):
    X_mb, _ = mnist.train.next_batch(mb_size)
    
    D_loss_curr, G_loss_curr, measure_curr, _ = sess.run(
        [D_loss, G_loss, measure, k_update],
        feed_dict={X: X_mb, z: sample_z(mb_size, z_dim)}
    )
    

    if it % 1000 == 0:
        
        samples = sess.run(G_sample, feed_dict={z: sample_z(16, z_dim)})

        fig = plot(samples)
        plt.savefig('out/{}/{}.png'.format(save_image_path, str(it//1000).zfill(3)), bbox_inches='tight')
        plt.show()
        plt.close(fig)
        
        print('Iter: {}'.format(it))
        print('k_curr: {:.4}'.format(sess.run(k)))
        print('D_loss: {:.4}'. format(D_loss_curr))
        print('G_loss: {:.4}'.format(G_loss_curr))
        print('measure: {:.4}'.format(measure_curr))
        print()
# Out:
# Iter: 0
# D_loss: 169.7
# G_loss: 393.6
# measure: 410.6
# k_curr: 0.0
# Iter: 1000
# D_loss: 96.53
# G_loss: 4.833
# measure: 187.8
# k_curr: 1.0
# Iter: 2000
# D_loss: 84.54
# G_loss: 5.667
# measure: 165.7
# k_curr: 1.0
# Iter: 3000
# D_loss: 81.3
# G_loss: 73.32
# measure: 105.4
# k_curr: 0.1855
# Iter: 4000
# D_loss: 47.53
# G_loss: 113.8
# measure: 130.4
# k_curr: 0.7136
# Iter: 5000
# D_loss: 34.53
# G_loss: 115.0
# measure: 140.5
# k_curr: 0.8754
# Iter: 6000
# D_loss: 16.76
# G_loss: 130.7
# measure: 149.4
# k_curr: 1.0
# Iter: 7000
# D_loss: 34.08
# G_loss: 114.2
# measure: 126.6
# k_curr: 0.7835
# Iter: 8000
# D_loss: 20.82
# G_loss: 117.2
# measure: 145.0
# k_curr: 1.0
# Iter: 9000
# D_loss: 22.01
# G_loss: 105.1
# measure: 134.4
# k_curr: 0.9987
# Iter: 10000
# D_loss: 60.83
# G_loss: 88.62
# measure: 115.8
# k_curr: 0.5361
# Iter: 11000
# D_loss: 55.02
# G_loss: 105.6
# measure: 120.8
# k_curr: 0.6089
# Iter: 12000
# D_loss: 29.34
# G_loss: 100.7
# measure: 121.0
# k_curr: 0.8718
# Iter: 13000
# D_loss: 47.58
# G_loss: 95.36
# measure: 109.3
# k_curr: 0.6321
# Iter: 14000
# D_loss: 20.24
# G_loss: 114.8
# measure: 141.7
# k_curr: 1.0
# Iter: 15000
# D_loss: 61.72
# G_loss: 83.39
# measure: 107.4
# k_curr: 0.471
# Iter: 16000
# D_loss: 50.76
# G_loss: 127.5
# measure: 139.4
# k_curr: 0.5125
# Iter: 17000
# D_loss: 57.54
# G_loss: 95.01
# measure: 115.6
# k_curr: 0.566
# Iter: 18000
# D_loss: 50.47
# G_loss: 144.7
# measure: 158.2
# k_curr: 0.5606
# Iter: 19000
# D_loss: 20.68
# G_loss: 115.8
# measure: 143.5
# k_curr: 1.0
# Iter: 20000
# D_loss: 69.74
# G_loss: 68.79
# measure: 137.4
# k_curr: 0.5922
